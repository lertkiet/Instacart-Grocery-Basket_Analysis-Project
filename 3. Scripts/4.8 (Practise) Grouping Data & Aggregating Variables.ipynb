# %% [markdown]
# ## 4.8 Grouping Data & Aggregating Variables

# %% [markdown]
# ### Contents

# %% [markdown]
# ### 1. Importing libraries and files
# ### 2. Grouping data with Panda
# ### 3. Aggregating Data with agg()
# ### 4. Deriving Columns with loc()

# %% [markdown]
# ## Importing libraries and files

# %%
import pandas as pd
import numpy as np
import os

# %%
# Creating a path for my ease of use
path = r'C:\Users\boss4048\Documents\10-2024 Instacart Basket Analysis'

# %%
# Transfering into a new dataframe fro this notebook
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_derived.pkl'))

# %%
# Testing the result from the new dataframe
ords_prods_merge.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             0             0   2539329        1             1
# 2             0             0   2539329        1             1
# 3             0             0   2539329        1             1
# 4             0             0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  total_days_since_last_order  \
# 0                   2                  8                          NaN
# 1                   2                  8                          NaN
# 2                   2                  8                          NaN
# 3                   2                  8                          NaN
# 4                   2                  8                          NaN
#
#    product_id  add_to_cart_order  ...  Unnamed: 0_y  \
# 0         196                  1  ...           195
# 1       14084                  2  ...         14084
# ...

# %%
# Creating a subset of ords_prods_merge dataframe within 1,000,0000 data
df = ords_prods_merge[:1000000]

# %%
df['order_number'].mean()
# Out:
# 17.313612

# %%
df.shape
# Out:
# (1000000, 21)

# %%
df.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             0             0   2539329        1             1
# 2             0             0   2539329        1             1
# 3             0             0   2539329        1             1
# 4             0             0   2539329        1             1
# 5             1             1   2398795        1             2
# 6             1             1   2398795        1             2
# 7             1             1   2398795        1             2
# 8             1             1   2398795        1             2
# 9             1             1   2398795        1             2
#
#    orders_day_of_week  order_hour_of_day  total_days_since_last_order  \
# 0                   2                  8                          NaN
# 1                   2                  8                          NaN
# ...

# %% [markdown]
# ## Grouping Data with pandas

# %%
df.groupby('product_name')

# %% [markdown]
# ## Aggregating Data with agg()
# ### Performing a Single Aggregation

# %%
# Grouping by department_id column and using .agg() function with order_number column
df.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %%
# Replacing the command above with .mean() function, aggregate function by square brackets
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: order_number, dtype: float64

# %%
# Replacing the command above with .mean() function, aggregate function by dot notation
df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: order_number, dtype: float64

# %% [markdown]
# ### Performing Multiple Aggregations

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.800024   1  99
# 2                17.091743   1  98
# 3                17.913544   1  99
# 4                17.893092   1  99
# 5                15.214270   1  99
# 6                15.382135   1  99
# 7                17.694027   1  99
# 8                16.458105   1  91
# 9                15.957363   1  99
# 10               20.091818   1  99
# 11               16.482026   1  99
# 12               15.615061   1  99
# 13               16.484023   1  99
# 14               17.524632   1  99
# 15               15.691875   1  99
# 16               18.014071   1  99
# 17               16.150593   1  99
# 18               19.602850   1  99
# 19               17.631340   1  99
# 20               17.138607   1  99
# 21               21.956893   1  97

# %% [markdown]
# ## Aggregating Data with transform()

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\boss4048\AppData\Local\Temp\ipykernel_27592\1681540670.py:1: FutureWarning: The provided callable <function max at 0x000001643F46BB00> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# The notebook still does not show 100 number of rows as I expected
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0              0             0   2539329        1             1
# 1              0             0   2539329        1             1
# 2              0             0   2539329        1             1
# 3              0             0   2539329        1             1
# 4              0             0   2539329        1             1
# 5              1             1   2398795        1             2
# 6              1             1   2398795        1             2
# 7              1             1   2398795        1             2
# 8              1             1   2398795        1             2
# 9              1             1   2398795        1             2
# 10             1             1   2398795        1             2
# 11             2             2    473747        1             3
# 12             2             2    473747        1             3
# 13             2             2    473747        1             3
# ...

# %%
# This command tells pandas not to assign any options regarding the maximum number of rows to display
pd.options.display.max_rows = None

# %%
# Now we can see the 100 rows as we executed
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0              0             0   2539329        1             1
# 1              0             0   2539329        1             1
# 2              0             0   2539329        1             1
# 3              0             0   2539329        1             1
# 4              0             0   2539329        1             1
# 5              1             1   2398795        1             2
# 6              1             1   2398795        1             2
# 7              1             1   2398795        1             2
# 8              1             1   2398795        1             2
# 9              1             1   2398795        1             2
# 10             1             1   2398795        1             2
# 11             2             2    473747        1             3
# 12             2             2    473747        1             3
# 13             2             2    473747        1             3
# ...

# %% [markdown]
# ## Deriving Columns with loc()

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check the frequency of the new “loyalty_flag” column using the value_counts() function
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# Show top 60 rows by 'user_id', 'loyalty_flag', 'order_number' columns
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# ...
